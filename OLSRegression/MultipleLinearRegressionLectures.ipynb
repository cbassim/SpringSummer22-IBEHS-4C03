# %% [markdown]
# # Multiple Linear Regression with Ordinary Least Squares Methodologies with Python

# %%
# %reset
import pandas as pd
import numpy as np
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
hypertension=pd.read_csv('Hypertension.csv')
hypertension
# Out:
#     Pt   BP  Age  Weight   Dur
# 0    1  105   47    85.4   5.1
# 1    2  115   49    94.2   3.8
# 2    3  116   49    95.3   8.2
# 3    4  117   50    94.7   5.8
# 4    5  112   51    89.4   7.0
# 5    6  121   48    99.5   9.3
# 6    7  121   49    99.8   2.5
# 7    8  110   47    90.9   6.2
# 8    9  110   49    89.2   7.1
# 9   10  114   48    92.7   5.6
# 10  11  114   47    94.4   5.3
# 11  12  115   49    94.1   5.6
# 12  13  114   50    91.6  10.2
# 13  14  106   45    87.1   5.6
# 14  15  125   52   101.3  10.0
# 15  16  114   46    94.5   7.4
# 16  17  106   46    87.0   3.6
# 17  18  113   46    94.5   4.3
# 18  19  110   48    90.5   9.0
# 19  20  122   56    95.7   7.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.regplot(x='Age',y='BP',data=hypertension,ci=None)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='BP'>

# %%
sns.regplot(x='Weight',y='BP',data=hypertension,ci=None)
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='BP'>

# %%
sns.regplot(x='Dur',y='BP',data=hypertension,ci=None)
# Out:
# <AxesSubplot:xlabel='Dur', ylabel='BP'>

# %%
from statsmodels.formula.api import ols

model1=ols('BP~Age',data=hypertension)
results1=model1.fit()
print(results1.summary2())
# Out:
#                  Results: Ordinary least squares
# ...
# Model:              OLS              Adj. R-squared:     0.403
# Dependent Variable: BP               AIC:                116.0041
# Date:               2022-03-14 14:01 BIC:                117.9956
# No. Observations:   20               Log-Likelihood:     -56.002
# Df Model:           1                F-statistic:        13.82
# Df Residuals:       18               Prob (F-statistic): 0.00157
# R-squared:          0.434            Scale:              17.596
# -------------------------------------------------------------------
#              Coef.    Std.Err.     t      P>|t|    [0.025    0.975]
# -------------------------------------------------------------------
# Intercept   44.4545    18.7277   2.3737   0.0289   5.1091   83.8000
# Age          1.4310     0.3849   3.7182   0.0016   0.6224    2.2395
# -----------------------------------------------------------------
# ...

# %%
model2=ols('BP~Weight',data=hypertension)
results2=model2.fit()
print(results2.summary2())
# Out:
#                  Results: Ordinary least squares
# ...
# Model:              OLS              Adj. R-squared:     0.897
# Dependent Variable: BP               AIC:                80.8172
# Date:               2022-03-14 14:01 BIC:                82.8087
# No. Observations:   20               Log-Likelihood:     -38.409
# Df Model:           1                F-statistic:        166.9
# Df Residuals:       18               Prob (F-statistic): 1.53e-10
# R-squared:          0.903            Scale:              3.0293
# ------------------------------------------------------------------
#               Coef.   Std.Err.     t     P>|t|    [0.025    0.975]
# ------------------------------------------------------------------
# Intercept     2.2053    8.6633   0.2546  0.8020  -15.9957  20.4063
# Weight        1.2009    0.0930  12.9174  0.0000    1.0056   1.3963
# -----------------------------------------------------------------
# Omnibus:              9.231        Durbin-Watson:           1.641
# ...

# %%
model3=ols('BP~Dur',data=hypertension)
results3=model3.fit()
print(results3.summary2())
# Out:
#                  Results: Ordinary least squares
# ...
# Model:              OLS              Adj. R-squared:     0.035
# Dependent Variable: BP               AIC:                125.6086
# Date:               2022-03-14 14:01 BIC:                127.6000
# No. Observations:   20               Log-Likelihood:     -60.804
# Df Model:           1                F-statistic:        1.688
# Df Residuals:       18               Prob (F-statistic): 0.210
# R-squared:          0.086            Scale:              28.443
# ------------------------------------------------------------------
#             Coef.    Std.Err.     t     P>|t|    [0.025    0.975]
# ------------------------------------------------------------------
# Intercept  109.2350    3.8563  28.3265  0.0000  101.1332  117.3367
# Dur          0.7411    0.5703   1.2993  0.2102   -0.4572    1.9393
# -----------------------------------------------------------------
# Omnibus:              0.757        Durbin-Watson:           2.199
# ...

# %%
sns.residplot('Dur','BP',data=hypertension)
# Out:
# C:\Users\nabil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Dur', ylabel='BP'>

# %%
sns.scatterplot(x=hypertension["Weight"],y=results1.resid)
plt.hlines(0,86,102,color='red')
plt.ylabel("resdiuals from BP~Age")
# Out:
# Text(0, 0.5, 'resdiuals from BP~Age')

# %%
model4=ols('BP~Age+Weight',data=hypertension)
results4=model4.fit()
print(results4.summary2())
# Out:
#                  Results: Ordinary least squares
# ...
# Model:              OLS              Adj. R-squared:     0.990
# Dependent Variable: BP               AIC:                34.3147
# Date:               2022-03-14 14:01 BIC:                37.3019
# No. Observations:   20               Log-Likelihood:     -14.157
# Df Model:           2                F-statistic:        978.2
# Df Residuals:       17               Prob (F-statistic): 2.81e-18
# R-squared:          0.991            Scale:              0.28376
# ------------------------------------------------------------------
#             Coef.    Std.Err.     t     P>|t|    [0.025    0.975]
# ------------------------------------------------------------------
# Intercept  -16.5794    3.0075  -5.5128  0.0000  -22.9246  -10.2342
# Age          0.7083    0.0535  13.2349  0.0000    0.5953    0.8212
# Weight       1.0330    0.0312  33.1542  0.0000    0.9672    1.0987
# -----------------------------------------------------------------
# ...

# %%
sns.scatterplot(x=hypertension["Dur"],y=results4.resid)
plt.hlines(0,2,11,color='red')
plt.ylabel("resdiuals from BP~Age+Weight")
# Out:
# Text(0, 0.5, 'resdiuals from BP~Age+Weight')

# %% [markdown]
# # Completion Time of a Maze

# %%
time=pd.read_csv('CompletionTime.csv')
time
# Out:
#     Completion   Brain  Height  Weight
# 0          124   81.69    64.5     118
# 1          150  103.84    73.3     143
# 2          128   96.54    68.8     172
# 3          134   95.15    65.0     147
# 4          110   92.88    69.0     146
# 5          131   99.13    64.5     138
# 6           98   85.43    66.0     175
# 7           84   90.49    66.3     134
# 8          147   95.55    68.8     172
# 9          124   83.39    64.5     118
# 10         128  107.95    70.0     151
# 11         124   92.41    69.0     155
# 12         147   85.65    70.5     155
# 13          90   87.89    66.0     146
# 14          96   86.54    68.0     135
# 15         120   85.22    68.5     127
# 16         102   94.51    73.5     178
# 17          84   80.80    66.3     136
# 18          86   88.91    70.0     180
# 19          84   90.59    76.5     186
# 20         134   79.06    62.0     122
# 21         128   95.50    68.0     132
# 22         102   83.18    63.0     114
# ...

# %%
sns.pairplot(time,kind='reg',diag_kind='hist')

# %%
# invoke a corr() on the pandas DataFrame of time to determine the correaltions between the variables
correlations=time.corr()
correlations
# Out:
#             Completion     Brain    Height    Weight
# Completion    1.000000  0.377815 -0.093156  0.002512
# Brain         0.377815  1.000000  0.588367  0.513487
# Height       -0.093156  0.588367  1.000000  0.699614
# Weight        0.002512  0.513487  0.699614  1.000000

# %%
correlations=time.corr()
cmap=sns.color_palette("mako",as_cmap=True)

sns.heatmap(correlations,annot=True,cmap=cmap)
# Out:
# <AxesSubplot:>

# %%
from mpl_toolkits.mplot3d import Axes3D

fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')

x=time['Brain']
y=time['Height']
z=time['Completion']
plt.xlabel("Brain")
plt.ylabel("Height")

ax.scatter(x,y,z)
ax.view_init(elev=20.,azim=20)

# ax.plot_surface(x,y,z,apla=0.2)

#for ii in range(0,360,1):
#        ax.view_init(elev=10.,azim=ii)
#        plt.savefig("movie%d.png" % ii)

#ax.dist

# %%
model5=ols('Completion~Brain+Height+Weight',data=time)
results5=model5.fit()
print(results5.summary2())
# Out:
#                  Results: Ordinary least squares
# ...
# Model:              OLS              Adj. R-squared:     0.233
# Dependent Variable: Completion       AIC:                338.5030
# Date:               2022-03-14 14:54 BIC:                345.0534
# No. Observations:   38               Log-Likelihood:     -165.25
# Df Model:           3                F-statistic:        4.741
# Df Residuals:       34               Prob (F-statistic): 0.00722
# R-squared:          0.295            Scale:              391.82
# ------------------------------------------------------------------
#             Coef.    Std.Err.     t     P>|t|    [0.025    0.975]
# ------------------------------------------------------------------
# Intercept  111.3536   62.9711   1.7683  0.0860  -16.6191  239.3263
# Brain        2.0604    0.5634   3.6567  0.0009    0.9153    3.2054
# Height      -2.7319    1.2294  -2.2221  0.0330   -5.2304   -0.2334
# Weight       0.0006    0.1971   0.0028  0.9977   -0.3999    0.4010
# ...

# %%
sns.residplot(results5.fittedvalues,results5.resid)
plt.xlabel("fitted values")
plt.ylabel("residuals")
# Out:
# C:\Users\nabil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'residuals')

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

fig=plt.figure(figsize=(12,8))
fig=sm.graphics.plot_regress_exog(results5,'Height',fig=fig)

# %%
sm.qqplot(results5.resid,line='s')
plt.show()
# Out:
# C:\Users\nabil\anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
import scipy
from scipy import stats

stats.shapiro(results5.resid)
# Out:
# ShapiroResult(statistic=0.9759781360626221, pvalue=0.5758413076400757)

# %% [markdown]
# # MLR and Babies1

# %%
babies=pd.read_csv('Babies1.csv')
babies
# Out:
#     headcirc  length  gestage  birthwt  momage  toxemia  sbp     sex grmhrm  \
# 0         27      41       29     1360      37        0   43    Male     No
# 1         29      40       31     1490      34        0   51    Male     No
# 2         30      38       33     1490      32        0   42  Female     No
# 3         28      38       31     1180      37        0   39  Female     No
# 4         29      38       30     1200      29        1   48  Female     No
# ..       ...     ...      ...      ...     ...      ...  ...     ...    ...
# 95        26      37       31      820      30        1   51  Female    Yes
# 96        27      40       29     1150      28        0   52    Male     No
# 97        28      35       32      880      35        1   47    Male     No
# 98        28      41       33     1320      36        1   40  Female     No
# 99        26      38       28     1080      36        0   50  Female     No
#
#     apgar5
# 0        7
# 1        8
# 2        0
# ...

# %%
sns.regplot("gestage","headcirc",data=babies)
# Out:
# C:\Users\nabil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gestage', ylabel='headcirc'>

# %%
model6=ols('headcirc~gestage',data=babies)
results6=model6.fit()
print(results6.summary2())
# Out:
#                  Results: Ordinary least squares
# ...
# Model:              OLS              Adj. R-squared:     0.605
# Dependent Variable: headcirc         AIC:                378.5662
# Date:               2022-03-14 16:11 BIC:                383.7766
# No. Observations:   100              Log-Likelihood:     -187.28
# Df Model:           1                F-statistic:        152.9
# Df Residuals:       98               Prob (F-statistic): 1.00e-21
# R-squared:          0.609            Scale:              2.5294
# -------------------------------------------------------------------
#              Coef.    Std.Err.      t      P>|t|    [0.025   0.975]
# -------------------------------------------------------------------
# Intercept    3.9143     1.8291    2.1399   0.0348   0.2844   7.5441
# gestage      0.7801     0.0631   12.3672   0.0000   0.6549   0.9052
# -----------------------------------------------------------------
# ...

# %%
model7=ols('headcirc~birthwt+gestage',data=babies)
results7=model7.fit()
print(results7.summary2())
# Out:
#                  Results: Ordinary least squares
# ...
# Model:              OLS              Adj. R-squared:     0.747
# Dependent Variable: headcirc         AIC:                335.1644
# Date:               2022-03-14 16:20 BIC:                342.9799
# No. Observations:   100              Log-Likelihood:     -164.58
# Df Model:           2                F-statistic:        147.1
# Df Residuals:       97               Prob (F-statistic): 4.28e-30
# R-squared:          0.752            Scale:              1.6229
# -------------------------------------------------------------------
#              Coef.    Std.Err.     t      P>|t|    [0.025    0.975]
# -------------------------------------------------------------------
# Intercept    8.3080     1.5789   5.2618   0.0000   5.1743   11.4418
# birthwt      0.0047     0.0006   7.4658   0.0000   0.0035    0.0060
# gestage      0.4487     0.0672   6.6730   0.0000   0.3153    0.5822
# ...

# %%
fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')

x=babies['birthwt']
y=babies['gestage']
z=babies['headcirc']
plt.xlabel("birthwt")
plt.ylabel("gestage")

ax.scatter(x,y,z,marker='x')
ax.view_init(elev=20.,azim=305)

# %%
fig=plt.figure(figsize=plt.figaspect(1)*2)
ax=fig.add_subplot(111,projection='3d')

x=babies['birthwt']
y=babies['gestage']
z=babies['headcirc']
plt.xlabel("birthwt")
plt.ylabel("gestage")

ax.scatter(x,y,z,marker='x',label="Raw Data")
ax.view_init(elev=0.,azim=305)

ax.scatter(x.values,y.values,results7.fittedvalues.values,label="Fited Values")

x1,y1=model7.exog_names[1:]

x_surf=np.arange(babies['birthwt'].min(), babies['birthwt'].max())
y_surf=np.arange(babies['gestage'].min(), babies['gestage'].max())
xS,yS=np.meshgrid(x_surf,y_surf)

exog=pd.DataFrame({x1: xS.ravel(), y1:yS.ravel()})
zS=results7.predict(exog=exog).values.reshape(xS.shape)
ax.plot_surface(xS,yS,zS,alpha=0.4,color='orange')

# %%
from statsmodels.stats.anova import anova_lm
anova_results7 = anova_lm(results7)
print(anova_results7)
# Out:
#             df      sum_sq     mean_sq           F        PR(>F)
# birthwt    1.0  405.059950  405.059950  249.587363  1.427424e-28
# gestage    1.0   72.266956   72.266956   44.529011  1.555501e-09
# Residual  97.0  157.423095    1.622919         NaN           NaN

# %%
np.mean(babies['headcirc'])
# Out:
# 26.45

# %%
sns.residplot(results7.fittedvalues,results7.resid)
plt.xlabel("fitted values")
plt.ylabel("residuals")
# Out:
# C:\Users\nabil\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'residuals')

# %%
sm.qqplot(results7.resid,line='s')
plt.show()
# Out:
# C:\Users\nabil\anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:993: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "bo" (-> marker='o'). The keyword argument will take precedence.
#   ax.plot(x, y, fmt, **plot_style)

# %%
stats.shapiro(results7.resid)
# Out:
# ShapiroResult(statistic=0.7306931018829346, pvalue=2.9787932103592096e-12)

# %%
fig=sm.graphics.influence_plot(results7,criterion='cooks')

# %%
predictions=results7.get_prediction(babies).summary_frame(alpha=0.05)
predictions
# Out:
#          mean   mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 0   27.729973  0.204559      27.323981      28.135966     25.169171
# 1   29.240036  0.226006      28.791478      29.688594     26.672141
# 2   30.137502  0.252006      29.637339      30.637664     27.560091
# 3   27.779228  0.171444      27.438960      28.119496     25.228020
# 4   27.424741  0.139953      27.146972      27.702510     24.881114
# ..        ...       ...            ...            ...           ...
# 95  26.082806  0.316703      25.454239      26.711373     23.477431
# 96  26.740394  0.130426      26.481534      26.999254     24.198763
# 97  26.814276  0.342311      26.134883      27.493668     24.196175
# 98  29.336413  0.247347      28.845498      29.827329     26.760782
# 99  25.961801  0.137887      25.688134      26.235469     23.418619
#
#     obs_ci_upper
# 0      30.290776
# 1      31.807931
# 2      32.714912
# 3      30.330436
# 4      29.968367
# ..           ...
# 95     28.688181
# ...

# %%
print(results7.predict())
# Out:
# [27.72997343 29.24003597 30.13750166 27.77922811 27.42474093 22.73068931
#  23.345418   26.3162884  27.09274924 25.23246322 24.12187884 27.09488109
#  26.69327108 27.68285059 25.79793723 27.07025375 25.93930573 30.09037883
#  29.00655364 27.21162225 25.20783588 26.57652991 23.95801485 30.09037883
#  28.03946962 24.02976502 26.74039391 25.72618705 23.9601467  27.70747793
#  26.45978875 24.69161655 29.0044218  27.68285059 25.93717388 25.93717388
#  25.93717388 29.35890898 29.16935172 26.52727523 26.34091574 26.92888525
#  27.23411774 29.09866746 23.10980383 22.44795231 27.42474093 23.98264219
#  26.90425791 23.43753182 21.83322362 23.43966367 27.65822325 25.84292821
#  24.42924319 23.55640483 22.44795231 21.73897795 24.6166686  22.3290793
#  26.97600808 27.77709626 25.93717388 27.42474093 26.95351259 29.64164598
#  29.47778199 25.89005105 28.48607062 24.49886152 25.51306837 25.1360857
#  31.03496736 25.01934454 28.22582911 28.4625092  28.36719761 26.26703372
# ...

# %%
dir(results7)
# Out:
# ['HC0_se',
#  'HC1_se',
#  'HC2_se',
#  'HC3_se',
#  '_HCCM',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abat_diagonal',
#  '_cache',
#  '_data_attr',
#  '_data_in_cache',
#  '_get_robustcov_results',
#  '_is_nested',
#  '_use_t',
#  '_wexog_singular_values',
#  'aic',
#  'bic',
#  'bse',
#  'centered_tss',
#  'compare_f_test',
#  'compare_lm_test',
#  'compare_lr_test',
#  'condition_number',
#  'conf_int',
#  'conf_int_el',
#  'cov_HC0',
#  'cov_HC1',
#  'cov_HC2',
#  'cov_HC3',
#  'cov_kwds',
#  'cov_params',
#  'cov_type',
#  'df_model',
#  'df_resid',
#  'eigenvals',
#  'el_test',
#  'ess',
# ...

# %%
results7.get_prediction(exog=dict(birthwt=1098.85,gestage=29)).summary_frame(alpha=0.05)
# Out:
#         mean   mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 0  26.499361  0.127608      26.246093      26.752628     23.958293
#
#    obs_ci_upper
# 0     29.040428

# %%
model9=ols('headcirc~gestage+toxemia',data=babies)
results9=model9.fit()
print(results9.summary2())
# Out:
#                  Results: Ordinary least squares
# ...
# Model:              OLS              Adj. R-squared:     0.646
# Dependent Variable: headcirc         AIC:                368.8183
# Date:               2022-03-15 19:40 BIC:                376.6338
# No. Observations:   100              Log-Likelihood:     -181.41
# Df Model:           2                F-statistic:        91.18
# Df Residuals:       97               Prob (F-statistic): 5.25e-23
# R-squared:          0.653            Scale:              2.2722
# ------------------------------------------------------------------
#                Coef.   Std.Err.     t     P>|t|    [0.025   0.975]
# ------------------------------------------------------------------
# Intercept      1.4956    1.8680   0.8006  0.4253  -2.2119   5.2030
# gestage        0.8740    0.0656  13.3222  0.0000   0.7438   1.0043
# toxemia       -1.4123    0.4062  -3.4773  0.0008  -2.2184  -0.6062
# -----------------------------------------------------------------
# ...

# %%
correlations=babies.corr()
correlations
# Out:
#           headcirc    length   gestage   birthwt    momage   toxemia  \
# headcirc  1.000000  0.712733  0.780692  0.798837  0.132119  0.132043
# length    0.712733  1.000000  0.675231  0.815552  0.217993  0.109024
# gestage   0.780692  0.675231  1.000000  0.659938  0.265840  0.411968
# birthwt   0.798837  0.815552  0.659938  1.000000  0.154572  0.011803
# momage    0.132119  0.217993  0.265840  0.154572  1.000000  0.114119
# toxemia   0.132043  0.109024  0.411968  0.011803  0.114119  1.000000
# sbp       0.304839  0.147435  0.280988  0.270567 -0.066749  0.074264
# apgar5    0.099715  0.164669  0.170156  0.150916  0.087356  0.109144
#
#                sbp    apgar5
# headcirc  0.304839  0.099715
# length    0.147435  0.164669
# gestage   0.280988  0.170156
# birthwt   0.270567  0.150916
# momage   -0.066749  0.087356
# toxemia   0.074264  0.109144
# sbp       1.000000  0.148706
# apgar5    0.148706  1.000000
